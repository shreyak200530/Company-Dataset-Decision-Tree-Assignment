# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
comp = pd.read_csv("/content/Company_Data.csv",encoding = 'latin2')
comp
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
comp.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
new = comp[['Sales','CompPrice','Income','Advertising','Population','Price','ShelveLoc','Age','Urban','US']]
new
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#     Urban   US
# 0     Yes  Yes
# ...

# %%
new.head(5)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Urban        400 non-null    object
#  9   US           400 non-null    object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 31.4+ KB

# %%
new.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Urban          0
# US             0
# dtype: int64

# %%
new.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age
# count  400.000000  400.000000
# mean   115.795000   53.322500
# std     23.676664   16.200297
# min     24.000000   25.000000
# 25%    100.000000   39.750000
# 50%    117.000000   54.500000
# 75%    131.000000   66.000000
# max    191.000000   80.000000

# %%
#new=pd.get_dummies(new,columns=['US'])
#new=pd.get_dummies(new,columns=['ShelveLoc'])
new=pd.get_dummies(new,columns=['ShelveLoc', 'US'])

# %%
new
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#       US  Urban_No  Urban_Yes
# ...

# %%
new.corr()
# Out:
#                      Sales  CompPrice    Income  Advertising  Population  \
# Sales             1.000000   0.064079  0.151951     0.269507    0.050471
# CompPrice         0.064079   1.000000 -0.080653    -0.024199   -0.094707
# Income            0.151951  -0.080653  1.000000     0.058995   -0.007877
# Advertising       0.269507  -0.024199  0.058995     1.000000    0.265652
# Population        0.050471  -0.094707 -0.007877     0.265652    1.000000
# Price            -0.444951   0.584848 -0.056698     0.044537   -0.012144
# Age              -0.231815  -0.100239 -0.004670    -0.004557   -0.042663
# Urban_No          0.015419  -0.066594 -0.037967    -0.042035    0.052025
# Urban_Yes        -0.015419   0.066594  0.037967     0.042035   -0.052025
# ShelveLoc_Bad    -0.393167  -0.035393  0.072017    -0.035217    0.039902
# ShelveLoc_Good    0.500510   0.026386 -0.012657     0.056149    0.007789
# ShelveLoc_Medium -0.073999   0.008683 -0.051392    -0.015929   -0.040640
# ...

# %%
sns.histplot(new['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.histplot(new['Population'])
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.lineplot(x='Advertising',y='Sales',data=new)
# Out:
# <Axes: xlabel='Advertising', ylabel='Sales'>

# %%
sns.boxplot(x='ShelveLoc_Good',y='Sales',data=new)
plt.title('ShelveLoc_Good')
plt.show()

# %%
sns.boxplot(x='ShelveLoc_Bad',y='Sales',data=new)
plt.title('ShelveLoc_Bad')
plt.show()

# %%
sns.histplot(x='Urban_No',y='Sales',data=new)
plt.title('Urban Vs Sales')
plt.show()

# %%
sns.lineplot(x='Income',y='Age',data=new)
plt.title('Income Vs Age')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import plot_tree
from sklearn.ensemble import GradientBoostingRegressor

# %%
X=new[['CompPrice', 'Advertising'	,'Population'	,'Price'	,'Age','US_Yes','ShelveLoc_Good',	'ShelveLoc_Medium','Urban_Yes']]
y=new['Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=88)

# %%
model=DecisionTreeClassifier(criterion='gini',max_depth=3,min_samples_split=12,min_samples_leaf=3,random_state=42)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=3, min_samples_split=12,
#                        random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

train_pred=model.predict(X_train)
test_pred=model.predict(X_test)

accuracy = accuracy_score(y_test, test_pred)
precision = precision_score(y_test, test_pred, average='weighted')
recall = recall_score(y_test, test_pred, average='weighted')
f1 = f1_score(y_test, test_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (weighted): {precision:.4f}")
print(f"Recall (weighted): {recall:.4f}")
print(f"F1 Score (weighted): {f1:.4f}")
# Out:
# Accuracy: 0.6100
# Precision (weighted): 0.6640
# Recall (weighted): 0.6100
# F1 Score (weighted): 0.6050

# %%
plt.figure(figsize=(10, 5))
plot_tree(model, feature_names=X.columns, filled=True, class_names=model.classes_.tolist())
plt.show()

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
models = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(
        criterion='gini',
        max_depth=3,
        min_samples_split=12,
        min_samples_leaf=3,
        random_state=42,
        ccp_alpha=ccp_alpha
    )
    clf.fit(X_train, y_train)
    models.append(clf)

# %%
train_scores = [clf.score(X_train, y_train) for clf in models]
test_scores = [clf.score(X_test, y_test) for clf in models]

plt.figure(figsize=(10,6))
plt.plot(ccp_alphas, train_scores, marker='o', label='Train Accuracy', drawstyle="steps-post")
plt.plot(ccp_alphas, test_scores, marker='o', label='Test Accuracy', drawstyle="steps-post")
plt.xlabel("Alpha")
plt.ylabel("Accuracy")
plt.title("Post-pruning: Accuracy vs CCP Alpha")
plt.legend()
plt.show()

# %%
best_alpha = ccp_alphas[test_scores.index(max(test_scores))]
print("Best alpha:", best_alpha)

pruned_model = DecisionTreeClassifier(
    criterion='gini',
    max_depth=3,
    min_samples_split=12,
    min_samples_leaf=3,
    random_state=42,
    ccp_alpha=best_alpha
)
pruned_model.fit(X_train, y_train)
# Out:
# Best alpha: 0.0
# DecisionTreeClassifier(ccp_alpha=np.float64(0.0), max_depth=3,
#                        min_samples_leaf=3, min_samples_split=12,
#                        random_state=42)

# %%
test_pred_pruned = pruned_model.predict(X_test)

accuracy = accuracy_score(y_test, test_pred_pruned)
precision = precision_score(y_test, test_pred_pruned, average='weighted')
recall = recall_score(y_test, test_pred_pruned, average='weighted')
f1 = f1_score(y_test, test_pred_pruned, average='weighted')

print(f"Pruned Tree Accuracy: {accuracy:.4f}")
print(f"Pruned Tree Precision: {precision:.4f}")
print(f"Pruned Tree Recall: {recall:.4f}")
print(f"Pruned Tree F1 Score: {f1:.4f}")
# Out:
# Pruned Tree Accuracy: 0.6100
# Pruned Tree Precision: 0.6640
# Pruned Tree Recall: 0.6100
# Pruned Tree F1 Score: 0.6050

# %%
plt.figure(figsize=(10, 5))
plot_tree(pruned_model, feature_names=X.columns, filled=True,
          class_names=[str(cls) for cls in pruned_model.classes_], fontsize=6)
plt.show()
